# %% [markdown]
# ## Report 1: Greedy heuristics
#
# * Radosław Winiecki, 148244
# * Oskar Szudzik, 148245
# * Alicja Kasicka, 148246

# %%
from scripts import *

print(get_dist_matrix("../data/TSPA.csv"))
# Out:
# [[  84 2032 2098 ... 4159 3783 1514]
#  [1633  483 2398 ... 3349 2266  817]
#  [ 720 1419 1462 ... 3640 3149  964]
#  ...
#  [2782 2371 3641 ... 1461 2908 2554]
#  [2558 1440 3302 ... 3060 1309 1773]
#  [1234  936 2062 ... 3651 2718  364]]

# %%
matrix = get_dist_matrix("../data/TSPA.csv")
sol, cost = random_solution(matrix)
print(sol, cost)
# Out:
# [ 48  33  69  21  89  80 149  63 161 137 123  40  86 174  25  54  67  58
#  115 170  27 181 108  18   3  94  93  46  20 129  51  72  34  29  99 150
#  147 164 189  68  97 107 198  41 143  57  64 140  42  73  16  56 113  17
#  126 175  83 120  85  91 176 196 122 103  38 116   8  24   1  35 110  53
#   98  30  52 124 102  92  82  65 182   9 193 163 152 101 167 169  47 185
#   81 194 133 135 165  75 118 134 132 188] 255946

# %% [markdown]
# ## RANDOM SOLUTION

# %% [markdown]
# Pseudocode:

# %%
np.random.seed(123)
random.seed(123)    
run_random_exp("../data/TSPA.csv")
# Out:
# Best cost: 240931
# Worst cost: 299471
# Mean cost after 200 solutions: 265532.71

# %%
run_random_exp("../data/TSPB.csv")
# Out:
# Best cost: 240594
# Worst cost: 290078
# Mean cost after 200 solutions: 267140.3

# %%
run_random_exp("../data/TSPC.csv")
# Out:
# Best cost: 189078
# Worst cost: 239771
# Mean cost after 200 solutions: 215533.645

# %%
run_random_exp("../data/TSPD.csv")
# Out:
# Best cost: 196601
# Worst cost: 247237
# Mean cost after 200 solutions: 218548.21

# %% [markdown]
# ## NEAREST NEIGHBOUR

# %% [markdown]
# ## GREEEDY CYCLE

# %% [markdown]
# ## CONCLUSIONS:
# 1.
# 2.
# 3.
