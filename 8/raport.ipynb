# %% [markdown]
# # Raport 8: Global convexity
#
# * Radosław Winiecki, 148244
# * Oskar Szudzik, 148245
#
# Source code: https://github.com/Oskshust/evo_comp/tree/main/8

# %% [markdown]
# ## Problem description:
#
# In our case, a path is a Hamiltonian cycle formed by connecting 50% of the vertices that appear on a plane. The best path is the one for which the cost of taking it is the lowest.
#
# The aim of the problem is to generate 1000 greedy solutions (local optima). For each solution, we calculate its similarity to the best solution (out of this 1000 solutions) and average similarity to all other local optima. We use two measures of similarity: number of common edges and common nodes.

# %%
run_global_convexity(a)
# Out:
# Correlation for Nodes Avg Sim: -0.588211660319315
# Correlation for Edges Avg Sim: -0.5058656363718076
# Correlation for Nodes Best Sim: -0.5315505830993916
# Correlation for Edges Best Sim: -0.08224160787365258

# %%
run_global_convexity(b)
# Out:
# Correlation for Nodes Avg Sim: -0.6242658856161374
# Correlation for Edges Avg Sim: -0.7304203787305503
# Correlation for Nodes Best Sim: -0.5119942539771707
# Correlation for Edges Best Sim: -0.05016095551943585

# %%
run_global_convexity(c)
# Out:
# Correlation for Nodes Avg Sim: -0.5252471658909305
# Correlation for Edges Avg Sim: -0.6426945735092179
# Correlation for Nodes Best Sim: -0.4412201551150975
# Correlation for Edges Best Sim: -0.10557125572179298

# %%
run_global_convexity(d)
# Out:
# Correlation for Nodes Avg Sim: -0.41961770485747785
# Correlation for Edges Avg Sim: -0.6414100915534547
# Correlation for Nodes Best Sim: -0.5777509372202544
# Correlation for Edges Best Sim: -0.15712027935942097

# %% [markdown]
# ## Conclusions
#
# 1. We observe that better the objective funtion the more similar are solutions, which would imply that algorithm is stuck at the local optima and produces similar results.
# 2. A similarity in case of edge similarity is much smaller than a node similarity.
# 3. At node similarity to the best solution we see a clear pattern of parralel lines.
